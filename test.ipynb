# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Downloads\sales.csv")
df
# Out:
#    id   item  quantity  price       timestamp
# 0   1  Bread         3    2.5  10-07-25 09:00
# 1   2   Milk         2    1.8  10-07-25 09:15
# 2   3   Eggs         1    3.0  10-07-25 09:30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3 non-null      int64
#  1   item       3 non-null      object
#  2   quantity   3 non-null      int64
#  3   price      3 non-null      float64
#  4   timestamp  3 non-null      object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 252.0+ bytes

# %%
df.head()
# Out:
#    id   item  quantity  price       timestamp
# 0   1  Bread         3    2.5  10-07-25 09:00
# 1   2   Milk         2    1.8  10-07-25 09:15
# 2   3   Eggs         1    3.0  10-07-25 09:30

# %%
df.tail(2)
# Out:
#    id  item  quantity  price       timestamp
# 1   2  Milk         2    1.8  10-07-25 09:15
# 2   3  Eggs         1    3.0  10-07-25 09:30

# %%
df.describe()
# Out:
#         id  quantity     price
# count  3.0       3.0  3.000000
# mean   2.0       2.0  2.433333
# std    1.0       1.0  0.602771
# min    1.0       1.0  1.800000
# 25%    1.5       1.5  2.150000
# 50%    2.0       2.0  2.500000
# 75%    2.5       2.5  2.750000
# max    3.0       3.0  3.000000

# %%
import pandas as pd
df2 = pd.read_csv(r"C:\Users\user\Desktop\Data sets\supermarket.csv")
df2
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
country_state = df2[["Country", "State", "Customer ID"]]
country_state
# Out:
#             Country       State Customer ID
# 0     United States    Kentucky    CG-12520
# 1     United States    Kentucky    CG-12520
# 2     United States  California    DV-13045
# 3     United States     Florida    SO-20335
# 4     United States     Florida    SO-20335
# ...             ...         ...         ...
# 9795  United States    Illinois    SH-19975
# 9796  United States        Ohio    CS-12490
# 9797  United States        Ohio    CS-12490
# 9798  United States        Ohio    CS-12490
# 9799  United States        Ohio    CS-12490
#
# [9800 rows x 3 columns]

# %%
high_sales = df2[df2["Sales"] > 200]
high_sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 7          8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# 10        11  CA-2015-115812  09/06/2015  14/06/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9782    9783  CA-2016-149748  31/05/2016  02/06/2016    Second Class
# 9787    9788  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9788    9789  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9790    9791  CA-2018-144491  27/03/2018  01/04/2018  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID      Customer Name    Segment        Country  \
# 0       CG-12520        Claire Gute   Consumer  United States
# ...
